# %%
import time
import copy
import numpy as np
from skimage.filters import gaussian
import cv2

import matplotlib.pyplot as plt
import pylab as pl

# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 10)

from tifffile import imread, imsave
import pickle

# %reload_ext autoreload
# %autoreload 2

from netsurface2d import NetSurf2d
from netsurface2dt import NetSurf2dt
from data3d import Data3d
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/prakash/anaconda/lib/python3.6/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['imread', 'imsave', 'copy']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Load time-lapse data...

# %%
# filename = '/Users/jug/Repositories/GIT/BobSeg/TestLapseData2d_151119-nmy2GFP-tagRfpPH-wt-04_w1LMM_488+488_LP_myTestCrop_bgrem.tif'
# filename = '/Users/jug/Dropbox/ProjectGoldstein/4MyosinMembraneWholeEmbryo.tif'
filename = '/Users/prakash/Git-repos/BobSeg/ProjectGoldstein/4MyosinMembraneWholeEmbryo.tif'

stack = imread(filename)
print ('Stack shape:',stack.shape)

segchannel = stack[:,0,:,:]
flowchannel = stack[:,1,:,:]
sigma = [0.,2.,2.]
segchannel_smooth = gaussian(segchannel,sigma)

print ('Segchannel shape:',segchannel.shape)
print ('Single image:',segchannel[0].shape)
# Out:
# Stack shape: (75, 2, 356, 610)
# Segchannel shape: (75, 356, 610)
# Single image: (356, 610)

# %%
max_rs = (segchannel[0].shape[1] / 4,
          segchannel[0].shape[1] / 4)

min_rs = (25,25)
print (min_rs, max_rs)
# Out:
# (25, 25) (152.5, 152.5)

# %%
pylab.rcParams['figure.figsize'] = (8, 10)
fig = plt.figure()
fig.suptitle('first and last frame', fontsize=16)
ax = fig.add_subplot(221)
ax.imshow(segchannel[0], plt.get_cmap('gray'))
ax = fig.add_subplot(222)
ax.imshow(segchannel[-1], plt.get_cmap('gray'))
ax = fig.add_subplot(223)
ax.imshow(segchannel_smooth[0], plt.get_cmap('gray'))
ax = fig.add_subplot(224)
ax.imshow(segchannel_smooth[-1], plt.get_cmap('gray'))

# %% [markdown]
# # Segmenting a cell

# %% [markdown]
# First we create a 'data' object.
# We give 3 parameters:
# - the channel (images) we want to use for segmenting the cell
# - the pixel size in x and y direction (in case the resolution is not isotropic)
# - silent: _true_ would mean that no outputs will be printed during segmentation
#
# Then we initialize an _objects_ list (one could add multiple cells to one data object.

# %%
data = Data3d( segchannel_smooth, pixelsize=(1.,1.), silent=False )
data.set_seg_params(num_columns=72,K=100,max_delta_k=4)
objects = []

# %% [markdown]
# ### Adding the cell to the _data_ object

# %% [markdown]
# You can name your cell if you wish. We then add the created _cell_ object to the _objects_ list we created above.

# %%
cell = data.init_object("name your cell")
objects.append(cell)

# %% [markdown]
# So far we did not say where this cell is located in the image. Hence, we add the object at a specific location, here at frame zero, at location (seed point) x=170, y=250. With _segment_it=True_ the object will be segmented right away.
#
# The second line takes the object, the cell, we just seeded at frame 0 and tracks it on all given _target_frames_. We just give a list of all frame ids from 1 to the number of images. The parameter _recenter_iterations_ should usually be at least 1. This is the number of times the segmentation tries to update the given seed point. Values >1 will take more time but might enhance the accuracy of tracking the object.

# %%
data.add_object_at( cell, min_rs, max_rs, frame=0, seed=(170,250), segment_it=True )
data.track(cell, seed_frame=0, target_frames=range(1,len(data.images)), recenter_iterations=1)
# Out:
# Added appearance for "name your cell" in frame 0 with seed coordinates [ 170.  250.]
#       Optimum energy:  0.0207501794527
#       Nodes in/out:  2999 4201
#       Area:  9776.0
# Added appearance for "name your cell" in frame 1 with seed coordinates [ 170.  250.]
#       Optimum energy:  0.0203234779986
#       Nodes in/out:  3051 4149
#       Area:  9915.0
#     Updated center to [171 255]
# Added appearance for "name your cell" in frame 2 with seed coordinates [ 171.  255.]
#       Optimum energy:  0.0195110703637
#       Nodes in/out:  3146 4054
#       Area:  10132.5
#     Updated center to [172 257]
# Added appearance for "name your cell" in frame 3 with seed coordinates [ 172.  257.]
#       Optimum energy:  0.0190742892947
#       Nodes in/out:  3184 4016
#       Area:  10271.0
#     Updated center to [173 259]
# Added appearance for "name your cell" in frame 4 with seed coordinates [ 173.  259.]
#       Optimum energy:  0.0196321674022
#       Nodes in/out:  3168 4032
#       Area:  10172.0
#     Updated center to [174 259]
# Added appearance for "name your cell" in frame 5 with seed coordinates [ 174.  259.]
#       Optimum energy:  0.0195860243343
#       Nodes in/out:  3215 3985
#       Area:  10308.5
#     Updated center to [174 259]
# Added appearance for "name your cell" in frame 6 with seed coordinates [ 174.  259.]
#       Optimum energy:  0.0192239711388
#       Nodes in/out:  3217 3983
#       Area:  10350.0
#     Updated center to [174 259]
# Added appearance for "name your cell" in frame 7 with seed coordinates [ 174.  259.]
#       Optimum energy:  0.0184603990487
#       Nodes in/out:  3164 4036
#       Area:  10155.0
#     Updated center to [174 259]
# Added appearance for "name your cell" in frame 8 with seed coordinates [ 174.  259.]
#       Optimum energy:  0.0207629257143
#       Nodes in/out:  3244 3956
#       Area:  10435.5
#     Updated center to [174 259]
# Added appearance for "name your cell" in frame 9 with seed coordinates [ 174.  259.]
#       Optimum energy:  0.0190177532101
#       Nodes in/out:  3309 3891
#       Area:  10654.5
#     Updated center to [174 259]
# Added appearance for "name your cell" in frame 10 with seed coordinates [ 174.  259.]
#       Optimum energy:  0.0183529736849
#       Nodes in/out:  3308 3892
#       Area:  10677.0
#     Updated center to [175 259]
# Added appearance for "name your cell" in frame 11 with seed coordinates [ 175.  259.]
#       Optimum energy:  0.0173241978713
#       Nodes in/out:  3271 3929
#       Area:  10543.0
#     Updated center to [175 259]
# Added appearance for "name your cell" in frame 12 with seed coordinates [ 175.  259.]
#       Optimum energy:  0.015320302703
#       Nodes in/out:  3282 3918
#       Area:  10585.5
#     Updated center to [175 260]
# Added appearance for "name your cell" in frame 13 with seed coordinates [ 175.  260.]
#       Optimum energy:  0.0164030476871
#       Nodes in/out:  3236 3964
#       Area:  10410.0
#     Updated center to [175 259]
# Added appearance for "name your cell" in frame 14 with seed coordinates [ 175.  259.]
#       Optimum energy:  0.0154578928266
#       Nodes in/out:  3223 3977
#       Area:  10347.5
#     Updated center to [175 259]
# Added appearance for "name your cell" in frame 15 with seed coordinates [ 175.  259.]
#       Optimum energy:  0.0152190603383
#       Nodes in/out:  3235 3965
#       Area:  10399.5
#     Updated center to [176 259]
# Added appearance for "name your cell" in frame 16 with seed coordinates [ 176.  259.]
#       Optimum energy:  0.0151064275665
#       Nodes in/out:  3309 3891
#       Area:  10670.5
#     Updated center to [176 260]
# Added appearance for "name your cell" in frame 17 with seed coordinates [ 176.  260.]
#       Optimum energy:  0.0141666671162
#       Nodes in/out:  3302 3898
#       Area:  10620.5
#     Updated center to [176 260]
# Added appearance for "name your cell" in frame 18 with seed coordinates [ 176.  260.]
#       Optimum energy:  0.013671220088
#       Nodes in/out:  3363 3837
#       Area:  10843.0
#     Updated center to [175 260]
# Added appearance for "name your cell" in frame 19 with seed coordinates [ 175.  260.]
#       Optimum energy:  0.0133530952655
#       Nodes in/out:  3297 3903
#       Area:  10625.5
#     Updated center to [174 260]
# Added appearance for "name your cell" in frame 20 with seed coordinates [ 174.  260.]
#       Optimum energy:  0.0126398650481
#       Nodes in/out:  3251 3949
#       Area:  10444.0
#     Updated center to [174 260]
# Added appearance for "name your cell" in frame 21 with seed coordinates [ 174.  260.]
#       Optimum energy:  0.0131403225371
#       Nodes in/out:  3290 3910
#       Area:  10570.0
#     Updated center to [174 261]
# Added appearance for "name your cell" in frame 22 with seed coordinates [ 174.  261.]
#       Optimum energy:  0.0128478949633
#       Nodes in/out:  3035 4165
#       Area:  9749.5
#     Updated center to [176 260]
# Added appearance for "name your cell" in frame 23 with seed coordinates [ 176.  260.]
#       Optimum energy:  0.0122840028429
#       Nodes in/out:  3312 3888
#       Area:  10659.5
#     Updated center to [175 260]
# Added appearance for "name your cell" in frame 24 with seed coordinates [ 175.  260.]
#       Optimum energy:  0.011715707226
#       Nodes in/out:  3338 3862
#       Area:  10725.5
#     Updated center to [175 260]
# Added appearance for "name your cell" in frame 25 with seed coordinates [ 175.  260.]
#       Optimum energy:  0.0126382612736
#       Nodes in/out:  3135 4065
#       Area:  10098.5
#     Updated center to [176 258]
# Added appearance for "name your cell" in frame 26 with seed coordinates [ 176.  258.]
#       Optimum energy:  0.0143890188985
#       Nodes in/out:  3334 3866
#       Area:  10744.0
#     Updated center to [176 259]
# Added appearance for "name your cell" in frame 27 with seed coordinates [ 176.  259.]
#       Optimum energy:  0.0121781262003
#       Nodes in/out:  3283 3917
#       Area:  10542.0
#     Updated center to [176 260]
# Added appearance for "name your cell" in frame 28 with seed coordinates [ 176.  260.]
#       Optimum energy:  0.0123714840965
#       Nodes in/out:  3252 3948
#       Area:  10403.5
#     Updated center to [176 260]
# Added appearance for "name your cell" in frame 29 with seed coordinates [ 176.  260.]
#       Optimum energy:  0.0128388187392
#       Nodes in/out:  3049 4151
#       Area:  9681.0
#     Updated center to [176 261]
# Added appearance for "name your cell" in frame 30 with seed coordinates [ 176.  261.]
#       Optimum energy:  0.0125133010401
#       Nodes in/out:  3116 4084
#       Area:  9915.5
#     Updated center to [176 261]
# Added appearance for "name your cell" in frame 31 with seed coordinates [ 176.  261.]
#       Optimum energy:  0.0111287570105
#       Nodes in/out:  3135 4065
#       Area:  10006.5
#     Updated center to [175 260]
# Added appearance for "name your cell" in frame 32 with seed coordinates [ 175.  260.]
#       Optimum energy:  0.0120265289174
#       Nodes in/out:  3082 4118
#       Area:  9837.0
#     Updated center to [175 260]
# Added appearance for "name your cell" in frame 33 with seed coordinates [ 175.  260.]
#       Optimum energy:  0.0119600336086
#       Nodes in/out:  3073 4127
#       Area:  9804.5
#     Updated center to [175 260]
# Added appearance for "name your cell" in frame 34 with seed coordinates [ 175.  260.]
#       Optimum energy:  0.0115871621026
#       Nodes in/out:  2916 4284
#       Area:  9205.5
#     Updated center to [177 260]
# Added appearance for "name your cell" in frame 35 with seed coordinates [ 177.  260.]
#       Optimum energy:  0.0112543658011
#       Nodes in/out:  2957 4243
#       Area:  9350.5
#     Updated center to [177 259]
# Added appearance for "name your cell" in frame 36 with seed coordinates [ 177.  259.]
#       Optimum energy:  0.0114800369155
#       Nodes in/out:  2900 4300
#       Area:  9135.0
#     Updated center to [178 259]
# Added appearance for "name your cell" in frame 37 with seed coordinates [ 178.  259.]
#       Optimum energy:  0.0115107124716
#       Nodes in/out:  2873 4327
#       Area:  9036.0
#     Updated center to [178 259]
# Added appearance for "name your cell" in frame 38 with seed coordinates [ 178.  259.]
#       Optimum energy:  0.0122570267791
#       Nodes in/out:  2829 4371
#       Area:  8906.0
#     Updated center to [178 259]
# Added appearance for "name your cell" in frame 39 with seed coordinates [ 178.  259.]
#       Optimum energy:  0.0121854248043
#       Nodes in/out:  2827 4373
#       Area:  8894.5
#     Updated center to [178 259]
# Added appearance for "name your cell" in frame 40 with seed coordinates [ 178.  259.]
#       Optimum energy:  0.0113801791526
#       Nodes in/out:  2800 4400
#       Area:  8805.0
#     Updated center to [178 260]
# Added appearance for "name your cell" in frame 41 with seed coordinates [ 178.  260.]
#       Optimum energy:  0.0116456925317
#       Nodes in/out:  2762 4438
#       Area:  8654.0
#     Updated center to [178 260]
# Added appearance for "name your cell" in frame 42 with seed coordinates [ 178.  260.]
#       Optimum energy:  0.0122346943821
#       Nodes in/out:  2744 4456
#       Area:  8618.5
#     Updated center to [179 260]
# Added appearance for "name your cell" in frame 43 with seed coordinates [ 179.  260.]
#       Optimum energy:  0.0124089267225
#       Nodes in/out:  2865 4335
#       Area:  9026.5
#     Updated center to [179 260]
# Added appearance for "name your cell" in frame 44 with seed coordinates [ 179.  260.]
#       Optimum energy:  0.0120933773601
#       Nodes in/out:  2802 4398
#       Area:  8834.0
#     Updated center to [180 261]
# Added appearance for "name your cell" in frame 45 with seed coordinates [ 180.  261.]
#       Optimum energy:  0.0111200375666
#       Nodes in/out:  2868 4332
#       Area:  9013.0
#     Updated center to [180 261]
# Added appearance for "name your cell" in frame 46 with seed coordinates [ 180.  261.]
#       Optimum energy:  0.0119639176175
#       Nodes in/out:  2823 4377
#       Area:  8869.5
#     Updated center to [180 261]
# Added appearance for "name your cell" in frame 47 with seed coordinates [ 180.  261.]
#       Optimum energy:  0.0115273772308
#       Nodes in/out:  2812 4388
#       Area:  8848.0
#     Updated center to [180 261]
# Added appearance for "name your cell" in frame 48 with seed coordinates [ 180.  261.]
#       Optimum energy:  0.0123971969231
#       Nodes in/out:  2736 4464
#       Area:  8601.0
#     Updated center to [180 261]
# Added appearance for "name your cell" in frame 49 with seed coordinates [ 180.  261.]
#       Optimum energy:  0.0120741071787
#       Nodes in/out:  2727 4473
#       Area:  8632.5
#     Updated center to [180 261]

# %% [markdown]
# The next command is optional. Without it you will have a segmented cell at every time point you indicated above. **The visualization routine in the next Section will allow you to compare the results of the above and the below segmentation.**
#
# So why another optional line? If you are interested in having a smoothly changing cell outline over time, the line below will do just that. Technically this is achieved by constraining the segmentation to only be allowed to change a certain amount from one time point to the next. (Note: the found solution is still globally optimal given the constraints we put in!)

# %%
data.segment2dt( cell, max_radial_delta=2 )
# Out:
# Results for frame 0:
#       Optimum energy:  0.726059424324
#       Area:  10097.5
# Results for frame 1:
#       Optimum energy:  0.726059424324
#       Area:  10061.5
# Results for frame 2:
#       Optimum energy:  0.726059424324
#       Area:  10081.0
# Results for frame 3:
#       Optimum energy:  0.726059424324
#       Area:  10167.5
# Results for frame 4:
#       Optimum energy:  0.726059424324
#       Area:  10279.0
# Results for frame 5:
#       Optimum energy:  0.726059424324
#       Area:  10353.0
# Results for frame 6:
#       Optimum energy:  0.726059424324
#       Area:  10281.0
# Results for frame 7:
#       Optimum energy:  0.726059424324
#       Area:  10245.5
# Results for frame 8:
#       Optimum energy:  0.726059424324
#       Area:  10408.5
# Results for frame 9:
#       Optimum energy:  0.726059424324
#       Area:  10520.5
# Results for frame 10:
#       Optimum energy:  0.726059424324
#       Area:  10555.5
# Results for frame 11:
#       Optimum energy:  0.726059424324
#       Area:  10466.0
# Results for frame 12:
#       Optimum energy:  0.726059424324
#       Area:  10517.0
# Results for frame 13:
#       Optimum energy:  0.726059424324
#       Area:  10386.0
# Results for frame 14:
#       Optimum energy:  0.726059424324
#       Area:  10322.0
# Results for frame 15:
#       Optimum energy:  0.726059424324
#       Area:  10331.5
# Results for frame 16:
#       Optimum energy:  0.726059424324
#       Area:  10504.0
# Results for frame 17:
#       Optimum energy:  0.726059424324
#       Area:  10587.5
# Results for frame 18:
#       Optimum energy:  0.726059424324
#       Area:  10598.0
# Results for frame 19:
#       Optimum energy:  0.726059424324
#       Area:  10529.5
# Results for frame 20:
#       Optimum energy:  0.726059424324
#       Area:  10428.0
# Results for frame 21:
#       Optimum energy:  0.726059424324
#       Area:  10589.0
# Results for frame 22:
#       Optimum energy:  0.726059424324
#       Area:  10641.0
# Results for frame 23:
#       Optimum energy:  0.726059424324
#       Area:  10619.0
# Results for frame 24:
#       Optimum energy:  0.726059424324
#       Area:  10667.0
# Results for frame 25:
#       Optimum energy:  0.726059424324
#       Area:  10614.5
# Results for frame 26:
#       Optimum energy:  0.726059424324
#       Area:  10632.0
# Results for frame 27:
#       Optimum energy:  0.726059424324
#       Area:  10520.0
# Results for frame 28:
#       Optimum energy:  0.726059424324
#       Area:  10389.0
# Results for frame 29:
#       Optimum energy:  0.726059424324
#       Area:  10209.5
# Results for frame 30:
#       Optimum energy:  0.726059424324
#       Area:  10083.5
# Results for frame 31:
#       Optimum energy:  0.726059424324
#       Area:  9957.0
# Results for frame 32:
#       Optimum energy:  0.726059424324
#       Area:  9732.5
# Results for frame 33:
#       Optimum energy:  0.726059424324
#       Area:  9688.0
# Results for frame 34:
#       Optimum energy:  0.726059424324
#       Area:  9509.0
# Results for frame 35:
#       Optimum energy:  0.726059424324
#       Area:  9334.5
# Results for frame 36:
#       Optimum energy:  0.726059424324
#       Area:  9189.0
# Results for frame 37:
#       Optimum energy:  0.726059424324
#       Area:  9061.5
# Results for frame 38:
#       Optimum energy:  0.726059424324
#       Area:  8938.0
# Results for frame 39:
#       Optimum energy:  0.726059424324
#       Area:  8782.0
# Results for frame 40:
#       Optimum energy:  0.726059424324
#       Area:  8731.0
# Results for frame 41:
#       Optimum energy:  0.726059424324
#       Area:  8626.5
# Results for frame 42:
#       Optimum energy:  0.726059424324
#       Area:  8682.5
# Results for frame 43:
#       Optimum energy:  0.726059424324
#       Area:  8804.0
# Results for frame 44:
#       Optimum energy:  0.726059424324
#       Area:  8970.5
# Results for frame 45:
#       Optimum energy:  0.726059424324
#       Area:  9024.5
# Results for frame 46:
#       Optimum energy:  0.726059424324
#       Area:  9047.5
# Results for frame 47:
#       Optimum energy:  0.726059424324
#       Area:  9110.5
# Results for frame 48:
#       Optimum energy:  0.726059424324
#       Area:  8915.5
# Results for frame 49:
#       Optimum energy:  0.726059424324
#       Area:  9054.0

# %% [markdown]
# # Visualizing the results

# %% [markdown]
# The following line creates images that show the outline of the segmented object(s).
# **Below we will export these images (they will e.g. be needed for the KymographMaker).**

# %%
pylab.rcParams['figure.figsize'] = (4, 5)
segimgs = data.create_segmentation_image()
imshow(segimgs[0])

# %% [markdown]
# This is just for you visual preasure (and of course to show if everyting worked ok).

# %%
pylab.rcParams['figure.figsize'] = (8, 10)
for frame in range(1,len(data.images),len(data.images)/5):
    fig = plt.figure()
    ax = plt.subplot(131)
    data.plot_minmax( frame, ax )
    ax = plt.subplot(132)
    ax.set_title('independent')
    data.plot_result( frame, ax )    
    ax = plt.subplot(133)
    ax.set_title('2dt')
    data.plot_2dt_result( frame, ax )

# %% [markdown]
# # FLOW

# %% [markdown]
# ### Look at the loaded flow channel images...

# %%
pylab.rcParams['figure.figsize'] = (8, 4)
fig = plt.figure()
fig.suptitle('first and last frame', fontsize=16)
ax = fig.add_subplot(121)
ax.imshow(flowchannel[0], plt.get_cmap('gray'))
ax = fig.add_subplot(122)
ax.imshow(flowchannel[-1], plt.get_cmap('gray'))

# %% [markdown]
# Flow computation is also part of the _data_ object we created above. Internally this uses a dense flow procedure implemented in OpenCV. The second cell then renders the image based on the computed flows.
#
# Parameters are:
# - the data2d object holding all computation results (including the computed flows)
# - the images you want the flow to be computed on
# - any second channel that will be used only for the visualization
# - a folder into which the visualization frames will be stored
# - _inline_: if _False_, a OpenCV window will pop open, otherwise visualizaiton will appear within jupyter (attention: much slower)

# %%
data.compute_flow( flowchannel );
# Out:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  ...done!

# %%
from moviemaker2d import MovieMaker2d
mm = MovieMaker2d( False )
mm.render_flow_movie( data, 
                      segchannel, 
                      flowchannel,
                      folder='/Users/jug/Repositories/GIT/BobSeg/frames3d_tempconsistent_newFeatureTest/', 
                      inline=True )

# %% [markdown]
# ## Export Data (e.g. for KymographMaker)

# %%
folder = '/Users/jug/Repositories/GIT/BobSeg/export/'

# %%
pylab.rcParams['figure.figsize'] = (6, 4)
fig = plt.figure()
fig.suptitle('flows', fontsize=16)
ax = fig.add_subplot(121)
ax.imshow(np.array(data.flows[1])[:,:,0], plt.get_cmap('gray'))
ax = fig.add_subplot(122)
ax.imshow(np.array(data.flows[1])[:,:,1], plt.get_cmap('gray'))

# %%
imsave(folder+'flow01.tiff', np.swapaxes(np.swapaxes(data.flows,1,3),2,3))
imsave(folder+'stack01.tiff', stack)
imsave(folder+'seg01.tiff', segimgs)
