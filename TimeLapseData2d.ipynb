# %%
import time
import copy
import numpy as np
from skimage.filters import gaussian
import cv2

import matplotlib.pyplot as plt
import pylab as pl

# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 10)

from tifffile import imread, imsave
import pickle

# %reload_ext autoreload
# %autoreload 2

from netsurface2d import NetSurf2d
from netsurface2dt import NetSurf2dt
from data3d import Data3d
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/prakash/anaconda/lib/python3.6/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Load time-lapse data...

# %%
# filename = '/Users/jug/Repositories/GIT/BobSeg/TestLapseData2d_151119-nmy2GFP-tagRfpPH-wt-04_w1LMM_488+488_LP_myTestCrop_bgrem.tif'
# filename = '/Users/jug/Dropbox/ProjectGoldstein/4MyosinMembraneWholeEmbryo.tif'
filename = '/Users/prakash/Git-repos/BobSeg/ProjectGoldstein/4MyosinMembraneWholeEmbryo.tif'

stack = imread(filename)
print ('Stack shape:',stack.shape)

segchannel = stack[:,0,:,:]
flowchannel = stack[:,1,:,:]
sigma = [0.,2.,2.]
segchannel_smooth = gaussian(segchannel,sigma)

print ('Segchannel shape:',segchannel.shape)
print ('Single image:',segchannel[0].shape)
# Out:
# Stack shape: (75, 2, 356, 610)
# Segchannel shape: (75, 356, 610)
# Single image: (356, 610)

# %%
max_rs = (segchannel[0].shape[1] / 4,
          segchannel[0].shape[1] / 4)

min_rs = (25,25)
print (min_rs, max_rs)
# Out:
# (25, 25) (152.5, 152.5)

# %%
pylab.rcParams['figure.figsize'] = (8, 10)
fig = plt.figure()
fig.suptitle('first and last frame', fontsize=16)
ax = fig.add_subplot(221)
ax.imshow(segchannel[0], plt.get_cmap('gray'))
ax = fig.add_subplot(222)
ax.imshow(segchannel[-1], plt.get_cmap('gray'))
ax = fig.add_subplot(223)
ax.imshow(segchannel_smooth[0], plt.get_cmap('gray'))
ax = fig.add_subplot(224)
ax.imshow(segchannel_smooth[-1], plt.get_cmap('gray'))

# %% [markdown]
# # Segmenting a cell

# %% [markdown]
# First we create a 'data' object.
# We give 3 parameters:
# - the channel (images) we want to use for segmenting the cell
# - the pixel size in x and y direction (in case the resolution is not isotropic)
# - silent: _true_ would mean that no outputs will be printed during segmentation
#
# Then we initialize an _objects_ list (one could add multiple cells to one data object.

# %%
data = Data3d( segchannel_smooth, pixelsize=(1.,1.), silent=False )
data.set_seg_params(num_columns=72,K=100,max_delta_k=4)
objects = []

# %% [markdown]
# ### Adding the cell to the _data_ object

# %% [markdown]
# You can name your cell if you wish. We then add the created _cell_ object to the _objects_ list we created above.

# %%
cell = data.init_object("name your cell")
objects.append(cell)

# %% [markdown]
# So far we did not say where this cell is located in the image. Hence, we add the object at a specific location, here at frame zero, at location (seed point) x=170, y=250. With _segment_it=True_ the object will be segmented right away.
# The second line takes the object, the cell, we just seeded at frame 0 and tracks it on all given _target_frames_. We just give a list of all frame ids from 1 to the number of images. The parameter _recenter_iterations_ should usually be at least 1. This is the number of times the segmentation tries to update the given seed point. Values >1 will take more time but might enhance the accuracy of tracking the object.

# %%
data.add_object_at( cell, min_rs, max_rs, frame=0, seed=(375,175), segment_it=True )
data.track(cell, seed_frame=0, target_frames=range(1,len(data.images)), recenter_iterations=1)
# Out:
# Added appearance for "name your cell" in frame 0 with seed coordinates [ 375.  175.]
#       Optimum energy:  25.580158344274754
#       Nodes in/out:  2088 5112
#       Area:  13049.0
# Added appearance for "name your cell" in frame 1 with seed coordinates [ 375.  175.]
#       Optimum energy:  25.56161953357885
#       Nodes in/out:  2027 5173
#       Area:  12487.5
#     Updated center to [ 360.79166667  176.63888889]
# Added appearance for "name your cell" in frame 2 with seed coordinates [ 361.  177.]
#       Optimum energy:  24.107312922491705
#       Nodes in/out:  2263 4937
#       Area:  13265.5
#     Updated center to [ 354.77777778  181.09722222]
# Added appearance for "name your cell" in frame 3 with seed coordinates [ 355.  181.]
#       Optimum energy:  24.25832442982236
#       Nodes in/out:  2332 4868
#       Area:  13331.0
#     Updated center to [ 351.83333333  184.25      ]
# Added appearance for "name your cell" in frame 4 with seed coordinates [ 352.  184.]
#       Optimum energy:  23.658442548192888
#       Nodes in/out:  2414 4786
#       Area:  13814.0
#     Updated center to [ 350.08333333  185.94444444]
# Added appearance for "name your cell" in frame 5 with seed coordinates [ 350.  186.]
#       Optimum energy:  23.380434112129937
#       Nodes in/out:  2435 4765
#       Area:  13886.5
#     Updated center to [ 348.41666667  186.52777778]
# Added appearance for "name your cell" in frame 6 with seed coordinates [ 348.  187.]
#       Optimum energy:  24.090390570803915
#       Nodes in/out:  2418 4782
#       Area:  13696.0
#     Updated center to [ 346.52777778  187.18055556]
# Added appearance for "name your cell" in frame 7 with seed coordinates [ 347.  187.]
#       Optimum energy:  23.426138899530198
#       Nodes in/out:  2446 4754
#       Area:  13931.5
#     Updated center to [ 345.81944444  186.875     ]
# Added appearance for "name your cell" in frame 8 with seed coordinates [ 346.  187.]
#       Optimum energy:  24.160073949008957
#       Nodes in/out:  2414 4786
#       Area:  13642.0
#     Updated center to [ 345.08333333  187.36111111]
# Added appearance for "name your cell" in frame 9 with seed coordinates [ 345.  187.]
#       Optimum energy:  23.355232453413027
#       Nodes in/out:  2414 4786
#       Area:  13641.0
#     Updated center to [ 344.81944444  186.36111111]
# Added appearance for "name your cell" in frame 10 with seed coordinates [ 345.  186.]
#       Optimum energy:  23.791603000671184
#       Nodes in/out:  2371 4829
#       Area:  13321.0
#     Updated center to [ 345.11111111  185.375     ]
# Added appearance for "name your cell" in frame 11 with seed coordinates [ 345.  185.]
#       Optimum energy:  23.132931999495433
#       Nodes in/out:  2328 4872
#       Area:  12970.5
#     Updated center to [ 345.73611111  184.23611111]
# Added appearance for "name your cell" in frame 12 with seed coordinates [ 346.  184.]
#       Optimum energy:  22.83035856703389
#       Nodes in/out:  2293 4907
#       Area:  12711.0
#     Updated center to [ 347.30555556  182.95833333]
# Added appearance for "name your cell" in frame 13 with seed coordinates [ 347.  183.]
#       Optimum energy:  22.92003659148295
#       Nodes in/out:  2302 4898
#       Area:  12769.5
#     Updated center to [ 347.80555556  182.11111111]
# Added appearance for "name your cell" in frame 14 with seed coordinates [ 348.  182.]
#       Optimum energy:  22.37376672879883
#       Nodes in/out:  2280 4920
#       Area:  12614.0
#     Updated center to [ 348.80555556  180.77777778]
# Added appearance for "name your cell" in frame 15 with seed coordinates [ 349.  181.]
#       Optimum energy:  21.4742553441548
#       Nodes in/out:  2256 4944
#       Area:  12474.5
#     Updated center to [ 349.09722222  179.66666667]
# Added appearance for "name your cell" in frame 16 with seed coordinates [ 349.  180.]
#       Optimum energy:  21.111369545248333
#       Nodes in/out:  2246 4954
#       Area:  12358.5
#     Updated center to [ 349.23611111  178.95833333]
# Added appearance for "name your cell" in frame 17 with seed coordinates [ 349.  179.]
#       Optimum energy:  20.519393333730918
#       Nodes in/out:  2376 4824
#       Area:  13517.0
#     Updated center to [ 350.47222222  175.72222222]
# Added appearance for "name your cell" in frame 18 with seed coordinates [ 350.  176.]
#       Optimum energy:  20.400827886105517
#       Nodes in/out:  2244 4956
#       Area:  12318.5
#     Updated center to [ 350.23611111  176.34722222]
# Added appearance for "name your cell" in frame 19 with seed coordinates [ 350.  176.]
#       Optimum energy:  21.136756878444803
#       Nodes in/out:  2282 4918
#       Area:  12581.0
#     Updated center to [ 349.05555556  176.41666667]
# Added appearance for "name your cell" in frame 20 with seed coordinates [ 349.  176.]
#       Optimum energy:  20.62575792722574
#       Nodes in/out:  2405 4795
#       Area:  13644.0
#     Updated center to [ 349.69444444  174.90277778]
# Added appearance for "name your cell" in frame 21 with seed coordinates [ 350.  175.]
#       Optimum energy:  20.28982707164591
#       Nodes in/out:  2280 4920
#       Area:  12595.0
#     Updated center to [ 349.41666667  176.02777778]
# Added appearance for "name your cell" in frame 22 with seed coordinates [ 349.  176.]
#       Optimum energy:  19.371705168259624
#       Nodes in/out:  2308 4892
#       Area:  12935.5
#     Updated center to [ 350.86111111  175.41666667]
# Added appearance for "name your cell" in frame 23 with seed coordinates [ 351.  175.]
#       Optimum energy:  19.475254051088406
#       Nodes in/out:  2262 4938
#       Area:  12621.5
#     Updated center to [ 352.59722222  174.63888889]
# Added appearance for "name your cell" in frame 24 with seed coordinates [ 353.  175.]
#       Optimum energy:  19.144822959887602
#       Nodes in/out:  2276 4924
#       Area:  12675.0
#     Updated center to [ 352.83333333  173.68055556]
# Added appearance for "name your cell" in frame 25 with seed coordinates [ 353.  174.]
#       Optimum energy:  18.28383471278949
#       Nodes in/out:  2271 4929
#       Area:  12623.0
#     Updated center to [ 352.11111111  172.93055556]
# Added appearance for "name your cell" in frame 26 with seed coordinates [ 352.  173.]
#       Optimum energy:  19.80188882783293
#       Nodes in/out:  2292 4908
#       Area:  12805.5
#     Updated center to [ 352.58333333  171.875     ]
# Added appearance for "name your cell" in frame 27 with seed coordinates [ 353.  172.]
#       Optimum energy:  19.65047725715232
#       Nodes in/out:  2240 4960
#       Area:  12446.0
#     Updated center to [ 354.66666667  171.13888889]
# Added appearance for "name your cell" in frame 28 with seed coordinates [ 355.  171.]
#       Optimum energy:  19.843563691655003
#       Nodes in/out:  2299 4901
#       Area:  12800.5
#     Updated center to [ 354.48611111  170.47222222]
# Added appearance for "name your cell" in frame 29 with seed coordinates [ 354.  170.]
#       Optimum energy:  20.321278357439322
#       Nodes in/out:  2278 4922
#       Area:  12621.5
#     Updated center to [ 355.22222222  169.38888889]
# Added appearance for "name your cell" in frame 30 with seed coordinates [ 355.  169.]
#       Optimum energy:  20.68949629905752
#       Nodes in/out:  2202 4998
#       Area:  12119.0
#     Updated center to [ 356.88888889  167.47222222]
# Added appearance for "name your cell" in frame 31 with seed coordinates [ 357.  167.]
#       Optimum energy:  20.600707211800284
#       Nodes in/out:  2279 4921
#       Area:  12589.5
#     Updated center to [ 356.375       168.08333333]
# Added appearance for "name your cell" in frame 32 with seed coordinates [ 356.  168.]
#       Optimum energy:  20.57834336659162
#       Nodes in/out:  2253 4947
#       Area:  12338.0
#     Updated center to [ 356.34722222  168.44444444]
# Added appearance for "name your cell" in frame 33 with seed coordinates [ 356.  168.]
#       Optimum energy:  20.386957644698178
#       Nodes in/out:  2230 4970
#       Area:  12154.0
#     Updated center to [ 355.94444444  168.44444444]
# Added appearance for "name your cell" in frame 34 with seed coordinates [ 356.  168.]
#       Optimum energy:  19.95301333797643
#       Nodes in/out:  2228 4972
#       Area:  12117.0
#     Updated center to [ 356.27777778  168.25      ]
# Added appearance for "name your cell" in frame 35 with seed coordinates [ 356.  168.]
#       Optimum energy:  20.715292870267294
#       Nodes in/out:  2228 4972
#       Area:  12124.0
#     Updated center to [ 355.81944444  168.33333333]
# Added appearance for "name your cell" in frame 36 with seed coordinates [ 356.  168.]
#       Optimum energy:  20.630812323824028
#       Nodes in/out:  2223 4977
#       Area:  12069.0
#     Updated center to [ 355.94444444  168.43055556]
# Added appearance for "name your cell" in frame 37 with seed coordinates [ 356.  168.]
#       Optimum energy:  20.822301794954967
#       Nodes in/out:  2224 4976
#       Area:  12072.5
#     Updated center to [ 356.55555556  167.76388889]
# Added appearance for "name your cell" in frame 38 with seed coordinates [ 357.  168.]
#       Optimum energy:  20.661606007353548
#       Nodes in/out:  2230 4970
#       Area:  12134.0
#     Updated center to [ 356.79166667  167.70833333]
# Added appearance for "name your cell" in frame 39 with seed coordinates [ 357.  168.]
#       Optimum energy:  20.989926543671174
#       Nodes in/out:  2294 4906
#       Area:  12592.5
#     Updated center to [ 355.51388889  167.80555556]
# Added appearance for "name your cell" in frame 40 with seed coordinates [ 356.  168.]
#       Optimum energy:  20.261659994346182
#       Nodes in/out:  2196 5004
#       Area:  11930.5
#     Updated center to [ 356.59722222  167.52777778]
# Added appearance for "name your cell" in frame 41 with seed coordinates [ 357.  168.]
#       Optimum energy:  20.614012401145914
#       Nodes in/out:  2285 4915
#       Area:  12574.0
#     Updated center to [ 356.94444444  167.09722222]
# Added appearance for "name your cell" in frame 42 with seed coordinates [ 357.  167.]
#       Optimum energy:  20.20826116932917
#       Nodes in/out:  2307 4893
#       Area:  12774.5
#     Updated center to [ 357.25        165.61111111]
# Added appearance for "name your cell" in frame 43 with seed coordinates [ 357.  166.]
#       Optimum energy:  20.513163320757783
#       Nodes in/out:  2274 4926
#       Area:  12505.5
#     Updated center to [ 355.95833333  166.01388889]
# Added appearance for "name your cell" in frame 44 with seed coordinates [ 356.  166.]
#       Optimum energy:  20.5418313060673
#       Nodes in/out:  2261 4939
#       Area:  12409.0
#     Updated center to [ 355.26388889  165.63888889]
# Added appearance for "name your cell" in frame 45 with seed coordinates [ 355.  166.]
#       Optimum energy:  19.56014482906926
#       Nodes in/out:  2238 4962
#       Area:  12266.5
#     Updated center to [ 354.25        166.18055556]
# Added appearance for "name your cell" in frame 46 with seed coordinates [ 354.  166.]
#       Optimum energy:  19.587652729074513
#       Nodes in/out:  2214 4986
#       Area:  12093.0
#     Updated center to [ 354.25        166.23611111]
# Added appearance for "name your cell" in frame 47 with seed coordinates [ 354.  166.]
#       Optimum energy:  20.57309149930392
#       Nodes in/out:  2268 4932
#       Area:  12543.5
#     Updated center to [ 354.66666667  166.02777778]
# Added appearance for "name your cell" in frame 48 with seed coordinates [ 355.  166.]
#       Optimum energy:  21.281630618320055
#       Nodes in/out:  2167 5033
#       Area:  11815.5
#     Updated center to [ 356.06944444  166.65277778]
# Added appearance for "name your cell" in frame 49 with seed coordinates [ 356.  167.]
#       Optimum energy:  20.706584953339082
#       Nodes in/out:  2337 4863
#       Area:  12956.5
#     Updated center to [ 353.41666667  167.19444444]
# Added appearance for "name your cell" in frame 50 with seed coordinates [ 353.  167.]
#       Optimum energy:  20.167645758489787
#       Nodes in/out:  2316 4884
#       Area:  12821.0
#     Updated center to [ 349.23611111  167.94444444]
# Added appearance for "name your cell" in frame 51 with seed coordinates [ 349.  168.]
#       Optimum energy:  21.10925515034822
#       Nodes in/out:  2257 4943
#       Area:  12311.0
#     Updated center to [ 347.98611111  168.63888889]
# Added appearance for "name your cell" in frame 52 with seed coordinates [ 348.  169.]
#       Optimum energy:  21.246346190874064
#       Nodes in/out:  2332 4868
#       Area:  12877.5
#     Updated center to [ 346.59722222  168.98611111]
# Added appearance for "name your cell" in frame 53 with seed coordinates [ 347.  169.]
#       Optimum energy:  20.3770312931496
#       Nodes in/out:  2350 4850
#       Area:  13019.0
#     Updated center to [ 346.11111111  169.25      ]
# Added appearance for "name your cell" in frame 54 with seed coordinates [ 346.  169.]
#       Optimum energy:  20.53576304950104
#       Nodes in/out:  2235 4965
#       Area:  12246.0
#     Updated center to [ 346.97222222  169.91666667]
# Added appearance for "name your cell" in frame 55 with seed coordinates [ 347.  170.]
#       Optimum energy:  20.195870900602376
#       Nodes in/out:  2148 5052
#       Area:  11844.0
#     Updated center to [ 351.65277778  170.41666667]
# Added appearance for "name your cell" in frame 56 with seed coordinates [ 352.  170.]
#       Optimum energy:  20.80062678469032
#       Nodes in/out:  2002 5198
#       Area:  10808.5
#     Updated center to [ 356.52777778  169.75      ]
# Added appearance for "name your cell" in frame 57 with seed coordinates [ 357.  170.]
#       Optimum energy:  19.49934767266486
#       Nodes in/out:  2029 5171
#       Area:  10893.5
#     Updated center to [ 359.79166667  169.58333333]
# Added appearance for "name your cell" in frame 58 with seed coordinates [ 360.  170.]
#       Optimum energy:  19.794743929659756
#       Nodes in/out:  2031 5169
#       Area:  10858.0
#     Updated center to [ 361.33333333  170.375     ]
# Added appearance for "name your cell" in frame 59 with seed coordinates [ 361.  170.]
#       Optimum energy:  19.435772062393486
#       Nodes in/out:  2040 5160
#       Area:  10936.5
#     Updated center to [ 361.84722222  170.84722222]
# Added appearance for "name your cell" in frame 60 with seed coordinates [ 362.  171.]
#       Optimum energy:  19.535843079012068
#       Nodes in/out:  2099 5101
#       Area:  11303.0
#     Updated center to [ 361.73611111  171.45833333]
# Added appearance for "name your cell" in frame 61 with seed coordinates [ 362.  171.]
#       Optimum energy:  19.455731721927414
#       Nodes in/out:  1972 5228
#       Area:  10461.0
#     Updated center to [ 362.11111111  172.34722222]
# Added appearance for "name your cell" in frame 62 with seed coordinates [ 362.  172.]
#       Optimum energy:  19.35437936440251
#       Nodes in/out:  2149 5051
#       Area:  11615.0
#     Updated center to [ 361.31944444  171.27777778]
# Added appearance for "name your cell" in frame 63 with seed coordinates [ 361.  171.]
#       Optimum energy:  19.445787974167505
#       Nodes in/out:  2106 5094
#       Area:  11338.5
#     Updated center to [ 360.66666667  171.86111111]
# Added appearance for "name your cell" in frame 64 with seed coordinates [ 361.  172.]
#       Optimum energy:  20.27022790353275
#       Nodes in/out:  2413 4787
#       Area:  13773.5
#     Updated center to [ 354.76388889  172.27777778]
# Added appearance for "name your cell" in frame 65 with seed coordinates [ 355.  172.]
#       Optimum energy:  20.13772960568619
#       Nodes in/out:  2358 4842
#       Area:  13264.5
#     Updated center to [ 351.44444444  172.125     ]
# Added appearance for "name your cell" in frame 66 with seed coordinates [ 351.  172.]
#       Optimum energy:  19.751320723311572
#       Nodes in/out:  2307 4893
#       Area:  12840.0
#     Updated center to [ 349.47222222  171.25      ]
# Added appearance for "name your cell" in frame 67 with seed coordinates [ 349.  171.]
#       Optimum energy:  19.702809267603115
#       Nodes in/out:  1990 5210
#       Area:  10737.5
#     Updated center to [ 352.88888889  171.25      ]
# Added appearance for "name your cell" in frame 68 with seed coordinates [ 353.  171.]
#       Optimum energy:  19.2086881292443
#       Nodes in/out:  2011 5189
#       Area:  10750.0
#     Updated center to [ 354.41666667  169.98611111]
# Added appearance for "name your cell" in frame 69 with seed coordinates [ 354.  170.]
#       Optimum energy:  19.41397781425791
#       Nodes in/out:  1957 5243
#       Area:  10419.0
#     Updated center to [ 355.79166667  169.55555556]
# Added appearance for "name your cell" in frame 70 with seed coordinates [ 356.  170.]
#       Optimum energy:  19.69742132000971
#       Nodes in/out:  2173 5027
#       Area:  11901.5
#     Updated center to [ 357.68055556  166.16666667]
# Added appearance for "name your cell" in frame 71 with seed coordinates [ 358.  166.]
#       Optimum energy:  19.908127388646008
#       Nodes in/out:  2174 5026
#       Area:  11884.0
#     Updated center to [ 359.27777778  163.91666667]
# Added appearance for "name your cell" in frame 72 with seed coordinates [ 359.  164.]
#       Optimum energy:  19.580826206225904
#       Nodes in/out:  2289 4911
#       Area:  12605.5
#     Updated center to [ 357.79166667  162.72222222]
# Added appearance for "name your cell" in frame 73 with seed coordinates [ 358.  163.]
#       Optimum energy:  18.76715090347677
#       Nodes in/out:  2241 4959
#       Area:  12343.5
#     Updated center to [ 358.30555556  161.56944444]
# Added appearance for "name your cell" in frame 74 with seed coordinates [ 358.  162.]
#       Optimum energy:  18.941683478119117
#       Nodes in/out:  2104 5096
#       Area:  11400.5
#     Updated center to [ 359.59722222  162.625     ]

# %% [markdown]
# The next command is optional. Without it you will have a segmented cell at every time point you indicated above. **The visualization routine in the next Section will allow you to compare the results of the above and the below segmentation.**
#
# So why another optional line? If you are interested in having a smoothly changing cell outline over time, the line below will do just that. Technically this is achieved by constraining the segmentation to only be allowed to change a certain amount from one time point to the next. (Note: the found solution is still globally optimal given the constraints we put in!)

# %%
data.segment2dt( cell, max_radial_delta=2 )
# Out:
# Results for frame 0:
#       Optimum energy:  1609.9737639461184
#       Area:  13513.0
# Results for frame 1:
#       Optimum energy:  1609.9737639461184
#       Area:  13240.5
# Results for frame 2:
#       Optimum energy:  1609.9737639461184
#       Area:  13411.0
# Results for frame 3:
#       Optimum energy:  1609.9737639461184
#       Area:  13729.0
# Results for frame 4:
#       Optimum energy:  1609.9737639461184
#       Area:  13924.5
# Results for frame 5:
#       Optimum energy:  1609.9737639461184
#       Area:  13907.5
# Results for frame 6:
#       Optimum energy:  1609.9737639461184
#       Area:  13853.5
# Results for frame 7:
#       Optimum energy:  1609.9737639461184
#       Area:  13979.0
# Results for frame 8:
#       Optimum energy:  1609.9737639461184
#       Area:  13562.0
# Results for frame 9:
#       Optimum energy:  1609.9737639461184
#       Area:  13347.5
# Results for frame 10:
#       Optimum energy:  1609.9737639461184
#       Area:  13186.0
# Results for frame 11:
#       Optimum energy:  1609.9737639461184
#       Area:  12958.5
# Results for frame 12:
#       Optimum energy:  1609.9737639461184
#       Area:  12877.5
# Results for frame 13:
#       Optimum energy:  1609.9737639461184
#       Area:  12858.0
# Results for frame 14:
#       Optimum energy:  1609.9737639461184
#       Area:  12608.0
# Results for frame 15:
#       Optimum energy:  1609.9737639461184
#       Area:  12343.0
# Results for frame 16:
#       Optimum energy:  1609.9737639461184
#       Area:  12417.5
# Results for frame 17:
#       Optimum energy:  1609.9737639461184
#       Area:  12503.0
# Results for frame 18:
#       Optimum energy:  1609.9737639461184
#       Area:  12593.5
# Results for frame 19:
#       Optimum energy:  1609.9737639461184
#       Area:  12676.0
# Results for frame 20:
#       Optimum energy:  1609.9737639461184
#       Area:  12927.0
# Results for frame 21:
#       Optimum energy:  1609.9737639461184
#       Area:  13130.5
# Results for frame 22:
#       Optimum energy:  1609.9737639461184
#       Area:  12979.5
# Results for frame 23:
#       Optimum energy:  1609.9737639461184
#       Area:  12774.0
# Results for frame 24:
#       Optimum energy:  1609.9737639461184
#       Area:  12649.5
# Results for frame 25:
#       Optimum energy:  1609.9737639461184
#       Area:  12559.0
# Results for frame 26:
#       Optimum energy:  1609.9737639461184
#       Area:  12718.5
# Results for frame 27:
#       Optimum energy:  1609.9737639461184
#       Area:  12756.0
# Results for frame 28:
#       Optimum energy:  1609.9737639461184
#       Area:  12731.5
# Results for frame 29:
#       Optimum energy:  1609.9737639461184
#       Area:  12677.0
# Results for frame 30:
#       Optimum energy:  1609.9737639461184
#       Area:  12673.0
# Results for frame 31:
#       Optimum energy:  1609.9737639461184
#       Area:  12431.0
# Results for frame 32:
#       Optimum energy:  1609.9737639461184
#       Area:  12293.0
# Results for frame 33:
#       Optimum energy:  1609.9737639461184
#       Area:  12332.0
# Results for frame 34:
#       Optimum energy:  1609.9737639461184
#       Area:  12259.0
# Results for frame 35:
#       Optimum energy:  1609.9737639461184
#       Area:  12177.0
# Results for frame 36:
#       Optimum energy:  1609.9737639461184
#       Area:  12175.0
# Results for frame 37:
#       Optimum energy:  1609.9737639461184
#       Area:  12311.5
# Results for frame 38:
#       Optimum energy:  1609.9737639461184
#       Area:  12447.5
# Results for frame 39:
#       Optimum energy:  1609.9737639461184
#       Area:  12490.0
# Results for frame 40:
#       Optimum energy:  1609.9737639461184
#       Area:  12222.0
# Results for frame 41:
#       Optimum energy:  1609.9737639461184
#       Area:  12235.5
# Results for frame 42:
#       Optimum energy:  1609.9737639461184
#       Area:  12312.5
# Results for frame 43:
#       Optimum energy:  1609.9737639461184
#       Area:  12382.0
# Results for frame 44:
#       Optimum energy:  1609.9737639461184
#       Area:  12425.5
# Results for frame 45:
#       Optimum energy:  1609.9737639461184
#       Area:  12362.0
# Results for frame 46:
#       Optimum energy:  1609.9737639461184
#       Area:  12282.5
# Results for frame 47:
#       Optimum energy:  1609.9737639461184
#       Area:  12206.0
# Results for frame 48:
#       Optimum energy:  1609.9737639461184
#       Area:  12128.0
# Results for frame 49:
#       Optimum energy:  1609.9737639461184
#       Area:  12057.5
# Results for frame 50:
#       Optimum energy:  1609.9737639461184
#       Area:  12024.0
# Results for frame 51:
#       Optimum energy:  1609.9737639461184
#       Area:  11941.5
# Results for frame 52:
#       Optimum energy:  1609.9737639461184
#       Area:  11914.5
# Results for frame 53:
#       Optimum energy:  1609.9737639461184
#       Area:  11694.0
# Results for frame 54:
#       Optimum energy:  1609.9737639461184
#       Area:  11458.0
# Results for frame 55:
#       Optimum energy:  1609.9737639461184
#       Area:  11431.5
# Results for frame 56:
#       Optimum energy:  1609.9737639461184
#       Area:  11218.0
# Results for frame 57:
#       Optimum energy:  1609.9737639461184
#       Area:  11007.0
# Results for frame 58:
#       Optimum energy:  1609.9737639461184
#       Area:  11013.5
# Results for frame 59:
#       Optimum energy:  1609.9737639461184
#       Area:  11013.0
# Results for frame 60:
#       Optimum energy:  1609.9737639461184
#       Area:  10967.0
# Results for frame 61:
#       Optimum energy:  1609.9737639461184
#       Area:  10942.5
# Results for frame 62:
#       Optimum energy:  1609.9737639461184
#       Area:  11185.0
# Results for frame 63:
#       Optimum energy:  1609.9737639461184
#       Area:  11118.0
# Results for frame 64:
#       Optimum energy:  1609.9737639461184
#       Area:  11117.5
# Results for frame 65:
#       Optimum energy:  1609.9737639461184
#       Area:  11144.5
# Results for frame 66:
#       Optimum energy:  1609.9737639461184
#       Area:  11120.0
# Results for frame 67:
#       Optimum energy:  1609.9737639461184
#       Area:  10812.0
# Results for frame 68:
#       Optimum energy:  1609.9737639461184
#       Area:  10735.5
# Results for frame 69:
#       Optimum energy:  1609.9737639461184
#       Area:  10631.0
# Results for frame 70:
#       Optimum energy:  1609.9737639461184
#       Area:  10861.0
# Results for frame 71:
#       Optimum energy:  1609.9737639461184
#       Area:  11171.0
# Results for frame 72:
#       Optimum energy:  1609.9737639461184
#       Area:  11563.5
# Results for frame 73:
#       Optimum energy:  1609.9737639461184
#       Area:  11707.0
# Results for frame 74:
#       Optimum energy:  1609.9737639461184
#       Area:  11704.0

# %% [markdown]
# # Visualizing the results

# %% [markdown]
# The following line creates images that show the outline of the segmented object(s).
# **Below we will export these images (they will e.g. be needed for the KymographMaker).**

# %%
pylab.rcParams['figure.figsize'] = (4, 5)
segimgs = data.create_segmentation_image()
imshow(segimgs[0])

# %% [markdown]
# This is just for you visual preasure (and of course to show if everyting worked ok).

# %%
pylab.rcParams['figure.figsize'] = (8, 10)
for frame in range(1,len(data.images),int(len(data.images)/7)):
    fig = plt.figure()
    ax = plt.subplot(131)
    data.plot_minmax( frame, ax )
    ax = plt.subplot(132)
    ax.set_title('independent')
    data.plot_result( frame, ax )    
    ax = plt.subplot(133)
    ax.set_title('2dt')
    data.plot_2dt_result( frame, ax )

# %% [markdown]
# # FLOW

# %% [markdown]
# ### Look at the loaded flow channel images...

# %%
pylab.rcParams['figure.figsize'] = (8, 4)
fig = plt.figure()
fig.suptitle('first and last frame', fontsize=16)
ax = fig.add_subplot(121)
ax.imshow(flowchannel[0], plt.get_cmap('gray'))
ax = fig.add_subplot(122)
ax.imshow(flowchannel[-1], plt.get_cmap('gray'))

# %% [markdown]
# Flow computation is also part of the _data_ object we created above. Internally this uses a dense flow procedure implemented in OpenCV. The second cell then renders the image based on the computed flows.
#
# Parameters are:
# - the data2d object holding all computation results (including the computed flows)
# - the images you want the flow to be computed on
# - any second channel that will be used only for the visualization
# - a folder into which the visualization frames will be stored
# - _inline_: if _False_, a OpenCV window will pop open, otherwise visualizaiton will appear within jupyter (attention: much slower)

# %%
data.compute_flow( flowchannel );
# Out:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  ...done!

# %%
from moviemaker2d import MovieMaker2d
mm = MovieMaker2d( False )
mm.render_flow_movie( data, 
                      segchannel, 
                      flowchannel,
                      folder='/Users/jug/Repositories/GIT/BobSeg/frames3d_tempconsistent_newFeatureTest/', 
                      inline=True )

# %% [markdown]
# ## Export Data (e.g. for KymographMaker)

# %%
folder = '/Users/jug/Repositories/GIT/BobSeg/export/'

# %%
pylab.rcParams['figure.figsize'] = (6, 4)
fig = plt.figure()
fig.suptitle('flows', fontsize=16)
ax = fig.add_subplot(121)
ax.imshow(np.array(data.flows[1])[:,:,0], plt.get_cmap('gray'))
ax = fig.add_subplot(122)
ax.imshow(np.array(data.flows[1])[:,:,1], plt.get_cmap('gray'))

# %%
imsave(folder+'flow01.tiff', np.swapaxes(np.swapaxes(data.flows,1,3),2,3))
imsave(folder+'stack01.tiff', stack)
imsave(folder+'seg01.tiff', segimgs)
